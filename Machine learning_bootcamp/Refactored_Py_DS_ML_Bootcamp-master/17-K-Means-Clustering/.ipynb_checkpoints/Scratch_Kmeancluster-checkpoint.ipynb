# %% [markdown]
# # K Means clustering
# > cluster unlabelled data in an unsupervised ML algorithm
# > chapter 10 in Intro to stat learning
# > Unsupervised ML algorithm
#   - attempt to group similar clusters together in data
#   - Examples
#   - cluster similar type of docs, cluster customer based on features, Market segmentation
#     identify similar groups
# > K means clustering - divides unlabelled data into distinct groups such that observations within each
#   group are similar
# > steps
#   - unlabelled observations
#   - each observation is randomly assigned to a cluster
#   - compute cluster centroid
#   - each observation is assigned to the nearest centroid
#   - new cluster centroid, segragated better
#   - Keep iterating 10 its  - Final results
# > choosing a K value - Elbow method - SSE compute for k =2,4,6,8
# > plot K(no of clusters) vs Error rate - K chosen based on the minimum error rate
# > Not determine any outcome but just identify the patterns

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import an artifical data 
from sklearn.datasets import make_blobs

# %%
# initialising inbuilt dataset from sklearn 
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8,random_state=101)

# %%
# explore the data 
print(data[0]) # 200 samples and 2 features 
print(data[0].shape) # (200,2)
print('-----------------------------')
print(data[1])
# Out:
# [[-6.42884095e+00  1.01411174e+01]
#  [ 5.86867888e+00  5.20110356e+00]
#  [-3.76109375e-01  3.26427943e+00]
#  [ 2.16679181e+00  9.56300522e+00]
#  [ 5.09508570e+00  7.20752718e+00]
#  [-1.08788882e+01 -6.11318040e+00]
#  [ 2.03405554e+00  9.76664755e+00]
#  [-1.71798771e+00  1.41401140e+00]
#  [ 1.16911341e+00  8.24556988e+00]
#  [-1.35185444e+00  3.13245345e+00]
#  [-6.18548214e+00  9.67406555e+00]
#  [-1.19856602e+00  2.50408937e+00]
#  [ 2.90296863e+00  7.91251003e+00]
#  [ 2.39250023e+00  5.38173971e+00]
#  [-5.27545147e+00  9.63836659e+00]
#  [-5.66814687e-01  5.60262755e-02]
#  [ 5.97336628e+00  5.87172022e+00]
#  [-2.31355268e+00  5.23980092e-01]
#  [-1.01344756e+01 -3.43130837e+00]
#  [-4.54082629e+00  1.13920174e+01]
#  [-1.04155833e+01 -5.67545836e+00]
#  [ 6.64796693e-01  9.42304718e-02]
#  [ 2.11460477e+00  3.55938488e+00]
#  [-1.11790221e+01 -9.30976605e+00]
#  [-6.63698251e+00  6.39426436e+00]
#  [-7.67422005e+00 -7.26839654e+00]
#  [-7.98668260e+00 -9.57113308e+00]
# ...

# %%
# plot the 4 blobs initialised 
sns.set_style('darkgrid')
plt.scatter(x=data[0][:,0],y=data[0][:,1], c=data[1],cmap='rainbow')
# plt.grid(True)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])   # fit it to the features
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[  5.41545402,   5.71409393],
#        [ -8.92965249,  -7.74388679],
#        [  0.33250207,   0.6136543 ],
#        [ -5.43564562,   7.56223985],
#        [  2.89741486,   7.98651499],
#        [-10.35008901,  -4.63054116],
#        [ -0.47545022,   4.08886774],
#        [ -2.29426163,   8.77011884]])

# %%
kmeans.labels_   # predicted by the kmeans algorithm
# concept of kmeans clustering is to determine/find the labels and assign the features
# Out:
# array([3, 0, 6, 4, 0, 5, 4, 2, 4, 6, 3, 6, 4, 4, 3, 2, 0, 2, 5, 7, 5, 2,
#        6, 1, 3, 1, 1, 2, 4, 0, 7, 1, 0, 2, 6, 3, 5, 5, 1, 2, 1, 7, 7, 7,
#        6, 4, 3, 6, 1, 6, 2, 3, 0, 2, 1, 6, 6, 2, 3, 4, 1, 4, 5, 7, 4, 2,
#        5, 0, 4, 1, 4, 6, 5, 6, 1, 0, 4, 2, 3, 6, 6, 1, 4, 1, 2, 2, 2, 3,
#        6, 5, 1, 1, 5, 6, 6, 1, 4, 3, 1, 0, 6, 5, 6, 2, 6, 6, 5, 0, 1, 1,
#        0, 7, 3, 4, 1, 0, 7, 3, 4, 7, 6, 3, 2, 3, 2, 0, 3, 2, 1, 7, 3, 7,
#        2, 1, 5, 3, 0, 6, 4, 2, 1, 0, 5, 7, 7, 4, 6, 1, 3, 3, 7, 7, 2, 0,
#        2, 3, 6, 4, 4, 2, 4, 2, 6, 3, 5, 3, 6, 0, 7, 2, 4, 2, 3, 7, 6, 3,
#        4, 4, 1, 4, 7, 1, 1, 7, 5, 1, 5, 1, 1, 2, 5, 0, 4, 3, 1, 6, 0, 4,
#        5, 2])

# %%
# Compare the klabels from the data blob(Original) created Vs K means determined label 
# K = 4
fig, (ax1,ax2) = plt.subplots(1,2,sharey= True, figsize=(10,6))
ax1.set_title('K means *n*')
ax2.set_title('Original')

ax1.scatter(data[0][:,0], data[0][:,1], c=kmeans.labels_, cmap='rainbow')  # label determined by K means algo 
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')  
# label that we knew already because of data initialisation

# %%
# K = 8

fig, (ax1,ax2) = plt.subplots(1,2,sharey= True, figsize=(10,6))
ax1.set_title('K means *n*')
ax2.set_title('Original')

ax1.scatter(data[0][:,0], data[0][:,1], c=kmeans.labels_, cmap='rainbow')  # label determined by K means algo 
ax2.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow')
